# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel(open("Descriptive-statistics-HomePrice.xlsx", "rb"), "Data")
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#      ID  Building  Year of sale  Month of sale Type of property  Property #  \
# 0  1030         1        2005.0           11.0        Apartment          30
# 1  1029         1        2005.0           10.0        Apartment          29
# 2  2002         2        2007.0            7.0        Apartment           2
# 3  2031         2        2007.0           12.0        Apartment          31
# 4  1049         1        2004.0           11.0        Apartment          49
#
#    Area (ft.)        Price Status Customer ID  ...       Y     M     D Gender  \
# 0    743.0856  246172.6760   Sold       C0028  ...  1986.0   6.0  21.0      F
# 1    756.2128  246331.9040   Sold       C0027  ...  1983.0   2.0  24.0      F
# 2    587.2808  209280.9104   Sold       C0112  ...  1985.0  12.0  27.0      M
# ...

# %%
df.describe()
# Out:
#                 ID    Building  Year of sale  Month of sale  Property #  \
# count   267.000000  267.000000    195.000000     195.000000  267.000000
# mean   2975.142322    2.947566   2006.333333       7.271795   27.580524
# std    1392.197474    1.391794      1.072941       3.378674   15.361437
# min    1002.000000    1.000000   2004.000000       1.000000    1.000000
# 25%    2015.500000    2.000000   2006.000000       4.000000   14.500000
# 50%    3024.000000    3.000000   2007.000000       8.000000   28.000000
# 75%    4031.500000    4.000000   2007.000000      10.000000   40.000000
# max    5052.000000    5.000000   2010.000000      12.000000   59.000000
#
#         Area (ft.)          Price            Y           M           D  \
# count   267.000000     267.000000   178.000000  178.000000  178.000000
# mean    936.221113  281171.901501  1960.325843    6.752809   15.449438
# std     284.895016   89119.120849    12.835575    3.450312    8.457285
# ...

# %%
df.dtypes
# Out:
# ID                           int64
# Building                     int64
# Year of sale               float64
# Month of sale              float64
# Type of property            object
# Property #                   int64
# Area (ft.)                 float64
# Price                      float64
# Status                      object
# Customer ID                 object
# Entity                      object
# Name                        object
# Surname                     object
# Age at time of purchase     object
# Interval                    object
# Y                          float64
# M                          float64
# D                          float64
# Gender                      object
# Country                     object
# State                       object
# Purpose                     object
# Deal satisfaction          float64
# Mortgage                    object
# Source                      object
# dtype: object

# %%
df.head()
# Out:
#      ID  Building  Year of sale  Month of sale Type of property  Property #  \
# 0  1030         1        2005.0           11.0        Apartment          30
# 1  1029         1        2005.0           10.0        Apartment          29
# 2  2002         2        2007.0            7.0        Apartment           2
# 3  2031         2        2007.0           12.0        Apartment          31
# 4  1049         1        2004.0           11.0        Apartment          49
#
#    Area (ft.)        Price Status Customer ID  ...       Y     M     D Gender  \
# 0    743.0856  246172.6760   Sold       C0028  ...  1986.0   6.0  21.0   True
# 1    756.2128  246331.9040   Sold       C0027  ...  1983.0   2.0  24.0   True
# 2    587.2808  209280.9104   Sold       C0112  ...  1985.0  12.0  27.0   True
# 3   1604.7464  452667.0064   Sold       C0160  ...  1985.0  12.0  27.0   True
# 4   1375.4508  467083.3132   Sold       C0014  ...  1979.0   5.0  15.0   True
#
# ...

# %%
df= df.astype({'Gender': 'bool'})
df.dtypes
# Out:
# ID                           int64
# Building                     int64
# Year of sale               float64
# Month of sale              float64
# Type of property            object
# Property #                   int64
# Area (ft.)                 float64
# Price                      float64
# Status                      object
# Customer ID                 object
# Entity                      object
# Name                        object
# Surname                     object
# Age at time of purchase     object
# Interval                    object
# Y                          float64
# M                          float64
# D                          float64
# Gender                        bool
# Country                     object
# State                       object
# Purpose                     object
# Deal satisfaction          float64
# Mortgage                    object
# Source                      object
# dtype: object

# %%
fig = plt.figure(figsize = (15,20))
ax = fig.gca()
df.hist(ax = ax)
# Out:
# <ipython-input-6-79d59cfc256a>:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df.hist(ax = ax)
# array([[<Axes: title={'center': 'ID'}>,
#         <Axes: title={'center': 'Building'}>,
#         <Axes: title={'center': 'Year of sale'}>],
#        [<Axes: title={'center': 'Month of sale'}>,
#         <Axes: title={'center': 'Property #'}>,
#         <Axes: title={'center': 'Area (ft.)'}>],
#        [<Axes: title={'center': 'Price'}>, <Axes: title={'center': 'Y'}>,
#         <Axes: title={'center': 'M'}>],
#        [<Axes: title={'center': 'D'}>,
#         <Axes: title={'center': 'Deal satisfaction'}>, <Axes: >]],
#       dtype=object)

# %%
fig = plt.figure(figsize = (10,5))
ax = fig.gca()
df["Area (ft.)"].hist(ax=ax, bins=7)
# Out:
# <Axes: >

# %%
fig = plt.figure(figsize = (10,5))
ax = fig.gca()
df["Price"].hist(ax=ax, bins=7)
# Out:
# <Axes: >

# %%
x = df[df["Mortgage"]== 'No']["Price"]
y = df[df["Mortgage"]== 'Yes']["Price"]

bins = 20

plt.hist(x, bins=bins, alpha=0.5, label='Without Mortgage')
plt.hist(y, bins=bins, alpha=0.5, label='With Mortgage')
plt.legend(loc='upper right')
plt.show()

# %%
x = df[df["Building"]== 1]["Price"]
y = df[df["Building"]== 5]["Price"]

bins = 20

plt.hist(x, bins=bins, alpha=0.5, label='Price of Building 1')
plt.hist(y, bins=bins, alpha=0.5, label='Price of Building 5')
plt.legend(loc='upper right')
plt.show()

# %%
x = df[df["Purpose"]== 'Home']["Price"]
y = df[df["Purpose"]== 'Investment']["Price"]

bins = 20

plt.hist(x, bins=bins, alpha=0.5, label='Home')
plt.hist(y, bins=bins, alpha=0.5, label='Investment')
plt.legend(loc='upper right')
plt.show()

# %%
df["Status"].unique()
# Out:
# array(['Sold', nan], dtype=object)

# %%
x = df[df["Status"]== "Sold"]["Price"]
print(x.shape)
y = df[df["Status"].isnull()]["Price"]
print(y.shape)
# Out:
# (195,)
# (72,)

# %%
x = df[df["Status"]== "Sold"]["Price"]
y = df[df["Status"].isnull()]["Price"]

bins = 20

plt.hist(x, bins=bins, alpha=0.5, label='Price of sold properties')
plt.hist(y, bins=bins, alpha=0.5, label='Price of unsold properties')
plt.legend(loc='upper right')
plt.show()

# %%
ax = df.plot.scatter(x='Price', y='Area (ft.)', figsize=(8, 4), marker='$\u25EF$')
ax.set_xlabel('Price')
ax.set_ylabel('Area')
ax.axhline(0, color='grey', lw=1)
ax.axvline(0, color='grey', lw=1)

plt.tight_layout()
plt.show()

# %%
df.corr()
# Out:
# <ipython-input-95-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                          ID  Building  Year of sale  Month of sale  \
# ID                 1.000000  0.999939      0.728397       0.166359
# Building           0.999939  1.000000      0.727657       0.166992
# Year of sale       0.728397  0.727657      1.000000      -0.111858
# Month of sale      0.166359  0.166992     -0.111858       1.000000
# Property #         0.031451  0.020420      0.119424      -0.039440
# Area (ft.)         0.001286 -0.001998     -0.020719      -0.041617
# Price              0.003574  0.000487     -0.012964      -0.031861
# Y                 -0.054818 -0.056278      0.032760      -0.012078
# M                  0.045796  0.045868      0.070546       0.111113
# ...

# %%
df["age_check"] = df["Age at time of purchase"].astype(str).str.isnumeric()
df["new_age"] = np.where(df["age_check"] == False,
                         np.NaN,
                         df["Age at time of purchase"])

df["new_age"] = df["new_age"].astype('Int32')

df[["Age at time of purchase", "age_check", "new_age"]].sample(10)
# Out:
#     Age at time of purchase  age_check  new_age
# 183                     NaN      False     <NA>
# 38                       35       True       35
# 35                       34       True       34
# 145                      48       True       48
# 161                      66       True       66
# 259                     NaN      False     <NA>
# 79                       43       True       43
# 179                     NaN      False     <NA>
# 125                      54       True       54
# 226                     NaN      False     <NA>

# %%
df2=df.head(179)
df2.info()
df2.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179 entries, 0 to 178
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       179 non-null    int64
#  1   Building                 179 non-null    int64
#  2   Year of sale             178 non-null    float64
#  3   Month of sale            178 non-null    float64
#  4   Type of property         179 non-null    object
#  5   Property #               179 non-null    int64
#  6   Area (ft.)               179 non-null    float64
#  7   Price                    179 non-null    float64
#  8   Status                   178 non-null    object
#  9   Customer ID              178 non-null    object
#  10  Entity                   178 non-null    object
#  11  Name                     178 non-null    object
#  12  Surname                  178 non-null    object
#  13  Age at time of purchase  179 non-null    object
# ...

# %%
df2.corr()
# Out:
# <ipython-input-99-e0c6714eb3b3>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df2.corr()
#                          ID  Building  Year of sale  Month of sale  \
# ID                 1.000000  0.999926      0.689003       0.210413
# Building           0.999926  1.000000      0.688865       0.210815
# Year of sale       0.689003  0.688865      1.000000      -0.110480
# Month of sale      0.210413  0.210815     -0.110480       1.000000
# Property #         0.038097  0.025932      0.021865      -0.029758
# Area (ft.)        -0.103585 -0.107813     -0.082569      -0.076451
# Price             -0.091730 -0.095622     -0.078439      -0.070791
# Y                 -0.054818 -0.056278      0.032760      -0.012078
# M                  0.045796  0.045868      0.070546       0.111113
# ...

# %%
df.cov()
# Out:
#                          ID     Building  Year of sale  Month of sale  \
# ID             1.938214e+06  1937.533806    972.702749     699.564129
# Building       1.937534e+03     1.937090      0.970790       0.701560
# Year of sale   9.727027e+02     0.970790      1.151203      -0.405498
# Month of sale  6.995641e+02     0.701560     -0.405498      11.415437
# Property #     6.726088e+02     0.436569      1.900344      -1.976262
# Area (ft.)     5.102033e+02    -0.792296     -5.813048     -36.767828
# Price          4.434169e+05    60.429144  -1114.573438   -8625.728343
#
#                   Property #    Area (ft.)         Price
# ID                672.608797  5.102033e+02  4.434169e+05
# Building            0.436569 -7.922963e-01  6.042914e+01
# Year of sale        1.900344 -5.813048e+00 -1.114573e+03
# Month of sale      -1.976262 -3.676783e+01 -8.625728e+03
# Property #        235.973755  1.301991e+03  3.829237e+05
# Area (ft.)       1301.991127  8.116517e+04  2.414772e+07
# ...

# %%
count_type= df["Type of property"].value_counts()
count_year= df["Year of sale"].value_counts()

print(count_year)
print(count_type)
# Out:
# 2007.0    102
# 2006.0     40
# 2005.0     27
# 2004.0     16
# 2008.0      9
# 2010.0      1
# Name: Year of sale, dtype: int64
# Apartment    259
# Office         8
# Name: Type of property, dtype: int64

# %%
from sklearn.utils import resample
results = []
for nrepeat in range(1000):
    sample = resample(df['Price'])
    results.append(sample.median())
results = pd.Series(results)
fig = plt.figure(figsize = (5,3))
ax = fig.gca()
results.hist(ax = ax)
# Out:
# <Axes: >
